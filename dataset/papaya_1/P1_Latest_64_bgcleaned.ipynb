# %% [markdown]
# ## 64x64

# %%
from feature_extraction import (extract_rgb_his, extract_lab, extract_glcm, extract_lbp)

image_dirs = [
    r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\processed\02_cleaned\overripe",
    r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\processed\02_cleaned\partial_ripe",
    r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\processed\02_cleaned\ripe",
    r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\processed\02_cleaned\unripe"
]

# %%
extract_rgb_his(image_dirs, 
                        rgb_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_rgb_features.csv",
                        his_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_his_features.csv",
                        dataset="papaya_1",
                        resize=(64,64))
# Out:
# Processing 'papaya_1' (RGB+HIS)...
# ...
# unripe: 100%|███████████████████████████████████████████████████████████████████████| 496/496 [00:03<00:00, 156.96it/s]
# RGB values for papaya_1 saved in C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_rgb_features.csv, HIS values for papaya_1 saved in C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_his_features.csv

# %%
extract_lab(image_dirs, 
            save_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_lab_features.csv", 
            dataset="papaya_1",
           resize=(64,64))
# Out:
# Processing 'papaya_1' (Lab)...
# ...
# unripe: 100%|███████████████████████████████████████████████████████████████████████| 496/496 [00:01<00:00, 483.50it/s]
# LAB values for papaya_1 saved in C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_lab_features.csv

# %%
extract_lbp(image_dirs, 
            save_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_lbp_features.csv",
            dataset="papaya_1",
           resize=(64,64))
# Out:
# Processing 'papaya_1' (LBP)...
# ...
# unripe: 100%|███████████████████████████████████████████████████████████████████████| 496/496 [00:00<00:00, 520.65it/s]
# LBP values for papaya_1 saved in C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_lbp_features.csv

# %%
extract_glcm(image_dirs, 
             save_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_glcm_features.csv", 
            dataset="papaya_1",
           resize=(64,64))
# Out:
# Processing 'papaya_1' (GLCM, angles=[0])...
# ...
# unripe: 100%|███████████████████████████████████████████████████████████████████████| 496/496 [00:01<00:00, 422.43it/s]
# GLCM values for papaya_1 (angles=[0]) saved in C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_glcm_features.csv

# %% [markdown]
# ## Split test train class

# %%
from knn_classification import split_per_class

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_rgb_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_rgb_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_rgb_test.csv",
    feature="64x64_papaya_1_rgb"
)

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_his_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_his_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_his_test.csv",
    feature="64x64_papaya_1_his"
)

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_lab_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_lab_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_lab_test.csv",
    feature="64x64_papaya_1lab"
)

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_lbp_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_lbp_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_lbp_test.csv",
    feature="64x64_papaya_1_lbp"
)

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_glcm_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_glcm_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_glcm_test.csv",
    feature="64x64_papaya_1_glcm"
)
# Out:
#  Train set for 64x64_papaya_1_rgb saved in C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_rgb_train.csv (1558 samples)
#  Test set for 64x64_papaya_1_rgb saved in C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_rgb_test.csv (393 samples)
#  Train set for 64x64_papaya_1_his saved in C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_his_train.csv (1558 samples)
#  Test set for 64x64_papaya_1_his saved in C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_his_test.csv (393 samples)
#  Train set for 64x64_papaya_1lab saved in C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_lab_train.csv (1558 samples)
#  Test set for 64x64_papaya_1lab saved in C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_lab_test.csv (393 samples)
#  Train set for 64x64_papaya_1_lbp saved in C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_lbp_train.csv (1558 samples)
#  Test set for 64x64_papaya_1_lbp saved in C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_lbp_test.csv (393 samples)
# ...

# %% [markdown]
# ## KNN = 1,3,5,7

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_rgb_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_rgb_test.csv",
    feature="64x64_papaya_1_rgb",
    class_order=['unripe', 'ripe', 'overripe']
)
# Out:
# --- KNN (k=1) on 64x64_papaya_1_rgb Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.9901    1.0000    0.9950       100
#         ripe     0.9130    0.9231    0.9180        91
#     overripe     0.9615    0.9009    0.9302       111
#
#    micro avg     0.9562    0.9404    0.9482       302
#    macro avg     0.9549    0.9413    0.9478       302
# weighted avg     0.9564    0.9404    0.9480       302
#
# Training time: 0.0020 seconds
# --- KNN (k=3) on 64x64_papaya_1_rgb Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.9899    0.9800    0.9849       100
#         ripe     0.9080    0.8681    0.8876        91
#     overripe     0.9107    0.9189    0.9148       111
#
#    micro avg     0.9362    0.9238    0.9300       302
#    macro avg     0.9362    0.9224    0.9291       302
# weighted avg     0.9361    0.9238    0.9298       302
#
# Training time: 0.0020 seconds
# ...

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_his_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_his_test.csv",
    feature="64x64_papaya_1_his",
   class_order=['unripe', 'ripe', 'overripe']
)
# Out:
# --- KNN (k=1) on 64x64_papaya_1_his Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.9703    0.9800    0.9751       100
#         ripe     0.8690    0.8022    0.8343        91
#     overripe     0.8430    0.9189    0.8793       111
#
#    micro avg     0.8922    0.9040    0.8980       302
#    macro avg     0.8941    0.9004    0.8962       302
# weighted avg     0.8930    0.9040    0.8975       302
#
# Training time: 0.0020 seconds
# --- KNN (k=3) on 64x64_papaya_1_his Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.9700    0.9700    0.9700       100
#         ripe     0.8966    0.8571    0.8764        91
#     overripe     0.8814    0.9369    0.9083       111
#
#    micro avg     0.9148    0.9238    0.9193       302
#    macro avg     0.9160    0.9214    0.9182       302
# weighted avg     0.9153    0.9238    0.9191       302
#
# Training time: 0.0020 seconds
# ...

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_lab_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_lab_test.csv",
    feature="64x64_papaya_1_lab",
    class_order=['unripe', 'ripe', 'overripe']
)
# Out:
# --- KNN (k=1) on 64x64_papaya_1_lab Feature ---
#               precision    recall  f1-score   support
#
#       unripe     1.0000    0.9900    0.9950       100
#         ripe     0.8817    0.9011    0.8913        91
#     overripe     0.9727    0.9640    0.9683       111
#
#    micro avg     0.9536    0.9536    0.9536       302
#    macro avg     0.9515    0.9517    0.9515       302
# weighted avg     0.9543    0.9536    0.9539       302
#
# Training time: 0.0020 seconds
# --- KNN (k=3) on 64x64_papaya_1_lab Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.9900    0.9900    0.9900       100
#         ripe     0.8864    0.8571    0.8715        91
#     overripe     0.9640    0.9640    0.9640       111
#
#    micro avg     0.9498    0.9404    0.9451       302
#    macro avg     0.9468    0.9370    0.9418       302
# weighted avg     0.9492    0.9404    0.9447       302
#
# Training time: 0.0020 seconds
# ...

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_lbp_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_lbp_test.csv",
    feature="64x64_papaya_1_lbp",
    class_order=['unripe', 'ripe', 'overripe']
)
# Out:
# --- KNN (k=1) on 64x64_papaya_1_lbp Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.8056    0.8700    0.8365       100
#         ripe     0.7447    0.7692    0.7568        91
#     overripe     1.0000    0.9820    0.9909       111
#
#    micro avg     0.8553    0.8808    0.8679       302
#    macro avg     0.8501    0.8737    0.8614       302
# weighted avg     0.8587    0.8808    0.8692       302
#
# Training time: 0.0010 seconds
# C:\Users\User\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
# ...

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_glcm_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_1\64x64_glcm_test.csv",
    feature="64x64_papaya_1_glcm",
    class_order=['unripe', 'ripe', 'overripe']
)
# Out:
# --- KNN (k=1) on 64x64_papaya_1_glcm Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.8585    0.9100    0.8835       100
#         ripe     0.7826    0.7912    0.7869        91
#     overripe     1.0000    0.9910    0.9955       111
#
#    micro avg     0.8864    0.9040    0.8951       302
#    macro avg     0.8804    0.8974    0.8886       302
# weighted avg     0.8876    0.9040    0.8955       302
#
# Training time: 0.0020 seconds
# --- KNN (k=3) on 64x64_papaya_1_glcm Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.9038    0.9400    0.9216       100
#         ripe     0.8391    0.8022    0.8202        91
#     overripe     1.0000    1.0000    1.0000       111
#
#    micro avg     0.9205    0.9205    0.9205       302
#    macro avg     0.9143    0.9141    0.9139       302
# weighted avg     0.9197    0.9205    0.9199       302
#
# Training time: 0.0030 seconds
# ...
