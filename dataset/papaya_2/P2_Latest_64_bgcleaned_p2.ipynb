# %% [markdown]
# ## 64x64

# %%
from feature_extraction import (extract_rgb_his, extract_lab, extract_glcm, extract_lbp)

image_dirs = [
    r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\processed\02_augmented\unripe",
    r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\processed\02_augmented\partial_ripe",
    r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\processed\02_augmented\ripe"
]

# %%
extract_rgb_his(image_dirs, 
                        rgb_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_rgb_features.csv",
                        his_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_his_features.csv",
                        dataset="papaya_2",
                        resize=(64,64))
# Out:
# Processing 'papaya_2' (RGB+HIS)...
# ...
# ripe: 100%|██████████████████████████████████████████████████████████████████████████| 300/300 [00:14<00:00, 20.67it/s]
# RGB values for papaya_2 saved in C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_rgb_features.csv, HIS values for papaya_2 saved in C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_his_features.csv

# %%
extract_lab(image_dirs, 
            save_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_lab_features.csv", 
            dataset="papaya_2",
           resize=(64,64))
# Out:
# Processing 'papaya_2' (Lab)...
# ...
# ripe: 100%|██████████████████████████████████████████████████████████████████████████| 300/300 [00:20<00:00, 14.29it/s]
# LAB values for papaya_2 saved in C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_lab_features.csv

# %%
extract_lbp(image_dirs, 
            save_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_lbp_features.csv",
            dataset="papaya_2",
           resize=(64,64))
# Out:
# Processing 'papaya_2' (LBP)...
# ...
# ripe: 100%|██████████████████████████████████████████████████████████████████████████| 300/300 [00:14<00:00, 20.23it/s]
# LBP values for papaya_2 saved in C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_lbp_features.csv

# %%
extract_glcm(image_dirs, 
             save_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_glcm_features.csv", 
            dataset="papaya_2",
           resize=(64,64))
# Out:
# Processing 'papaya_2' (GLCM, angles=[0])...
# ...
# ripe: 100%|██████████████████████████████████████████████████████████████████████████| 300/300 [00:15<00:00, 19.97it/s]
# GLCM values for papaya_2 (angles=[0]) saved in C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_glcm_features.csv

# %% [markdown]
# ## Split test train class

# %%
from knn_classification import split_per_class

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_rgb_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_rgb_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_rgb_test.csv",
    feature="64x64_papaya_2_rgb"
)

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_his_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_his_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_his_test.csv",
    feature="64x64_papaya_2_his"
)

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_lab_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_lab_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_lab_test.csv",
    feature="64x64_papaya_2_lab"
)

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_lbp_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_lbp_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_lbp_test.csv",
    feature="64x64_papaya_2_lbp"
)

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_glcm_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_glcm_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_glcm_test.csv",
    feature="64x64_papaya_2_glcm"
)
# Out:
#  Train set for 64x64_papaya_2_rgb saved in C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_rgb_train.csv (731 samples)
#  Test set for 64x64_papaya_2_rgb saved in C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_rgb_test.csv (183 samples)
#  Train set for 64x64_papaya_2_his saved in C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_his_train.csv (731 samples)
#  Test set for 64x64_papaya_2_his saved in C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_his_test.csv (183 samples)
#  Train set for 64x64_papaya_2_lab saved in C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_lab_train.csv (731 samples)
#  Test set for 64x64_papaya_2_lab saved in C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_lab_test.csv (183 samples)
#  Train set for 64x64_papaya_2_lbp saved in C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_lbp_train.csv (731 samples)
#  Test set for 64x64_papaya_2_lbp saved in C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_lbp_test.csv (183 samples)
# ...

# %% [markdown]
# ## KNN = 1,3,5,7

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_rgb_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_rgb_test.csv",
    feature="64x64_papaya_2_rgb",
    class_order=['unripe', 'partial_ripe', 'ripe']
)
# Out:
# --- KNN (k=1) on 64x64_papaya_2_rgb Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.7727    0.8226    0.7969        62
# partial_ripe     0.6207    0.5902    0.6050        61
#         ripe     0.7797    0.7667    0.7731        60
#
#     accuracy                         0.7268       183
#    macro avg     0.7244    0.7265    0.7250       183
# weighted avg     0.7243    0.7268    0.7251       183
#
# Training time: 0.0010 seconds
# --- KNN (k=3) on 64x64_papaya_2_rgb Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.7273    0.7742    0.7500        62
# partial_ripe     0.5424    0.5246    0.5333        61
#         ripe     0.7586    0.7333    0.7458        60
#
#     accuracy                         0.6776       183
#    macro avg     0.6761    0.6774    0.6764       183
# weighted avg     0.6759    0.6776    0.6764       183
#
# Training time: 0.0010 seconds
# ...

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_his_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_his_test.csv",
    feature="64x64_papaya_2_his",
    class_order=['unripe', 'partial_ripe', 'ripe']
)
# Out:
# --- KNN (k=1) on 64x64_papaya_2_his Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.8793    0.8226    0.8500        62
# partial_ripe     0.6667    0.6230    0.6441        61
#         ripe     0.6765    0.7667    0.7188        60
#
#     accuracy                         0.7377       183
#    macro avg     0.7408    0.7374    0.7376       183
# weighted avg     0.7419    0.7377    0.7383       183
#
# Training time: 0.0010 seconds
# --- KNN (k=3) on 64x64_papaya_2_his Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.8596    0.7903    0.8235        62
# partial_ripe     0.6140    0.5738    0.5932        61
#         ripe     0.6812    0.7833    0.7287        60
#
#     accuracy                         0.7158       183
#    macro avg     0.7183    0.7158    0.7151       183
# weighted avg     0.7193    0.7158    0.7157       183
#
# Training time: 0.0010 seconds
# ...

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_lab_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_lab_test.csv",
    feature="64x64_papaya_2_lab",
    class_order=['unripe', 'partial_ripe', 'ripe']
)
# Out:
# --- KNN (k=1) on 64x64_papaya_2_lab Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.8871    0.8871    0.8871        62
# partial_ripe     0.6765    0.7541    0.7132        61
#         ripe     0.7925    0.7000    0.7434        60
#
#     accuracy                         0.7814       183
#    macro avg     0.7853    0.7804    0.7812       183
# weighted avg     0.7859    0.7814    0.7820       183
#
# Training time: 0.0010 seconds
# --- KNN (k=3) on 64x64_papaya_2_lab Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.8548    0.8548    0.8548        62
# partial_ripe     0.7213    0.7213    0.7213        61
#         ripe     0.8333    0.8333    0.8333        60
#
#     accuracy                         0.8033       183
#    macro avg     0.8032    0.8032    0.8032       183
# weighted avg     0.8033    0.8033    0.8033       183
#
# Training time: 0.0010 seconds
# ...

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_lbp_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_lbp_test.csv",
    feature="64x64_papaya_2_lbp",
    class_order=['unripe', 'ripe', 'overripe']
)
# Out:
# --- KNN (k=1) on 64x64_papaya_2_lbp Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.5636    0.5000    0.5299        62
#         ripe     0.5667    0.5667    0.5667        60
#     overripe     0.0000    0.0000    0.0000         0
#
#    micro avg     0.5652    0.5328    0.5485       122
#    macro avg     0.3768    0.3556    0.3655       122
# weighted avg     0.5651    0.5328    0.5480       122
#
# Training time: 0.0010 seconds
# C:\Users\User\anaconda3\envs\GPU\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_glcm_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\papaya_2\64x64_glcm_test.csv",
    feature="64x64_papaya_2_glcm",
    class_order=['unripe', 'partial_ripe', 'ripe']
)
# Out:
# --- KNN (k=1) on 64x64_papaya_2_glcm Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.7377    0.7258    0.7317        62
# partial_ripe     0.6197    0.7213    0.6667        61
#         ripe     0.7843    0.6667    0.7207        60
#
#     accuracy                         0.7049       183
#    macro avg     0.7139    0.7046    0.7064       183
# weighted avg     0.7137    0.7049    0.7064       183
#
# Training time: 0.0010 seconds
# --- KNN (k=3) on 64x64_papaya_2_glcm Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.6731    0.5645    0.6140        62
# partial_ripe     0.5750    0.7541    0.6525        61
#         ripe     0.7843    0.6667    0.7207        60
#
#     accuracy                         0.6612       183
#    macro avg     0.6775    0.6618    0.6624       183
# weighted avg     0.6769    0.6612    0.6618       183
#
# Training time: 0.0020 seconds
# ...
