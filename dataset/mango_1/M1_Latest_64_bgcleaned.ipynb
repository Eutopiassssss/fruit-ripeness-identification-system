# %% [markdown]
# ## 64x64

# %%
from feature_extraction import (extract_rgb_his, extract_lab, extract_glcm, extract_lbp)

image_dirs = [
    r"C:\Users\User\Desktop\FYP\Dataset\mango_1\processed\02_augmented\ripe",
    r"C:\Users\User\Desktop\FYP\Dataset\mango_1\processed\02_augmented\overripe",
    r"C:\Users\User\Desktop\FYP\Dataset\mango_1\processed\01_cleaned\unripe"
]

# %%
extract_rgb_his(image_dirs, 
                        rgb_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_rgb_features.csv",
                        his_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_his_features.csv",
                        dataset="mango_1",
                        resize=(64,64))
# Out:
# Processing 'mango_1' (RGB+HIS)...
# ...
# unripe: 100%|███████████████████████████████████████████████████████████████████████| 911/911 [00:06<00:00, 149.79it/s]
# RGB values for mango_1 saved in C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_rgb_features.csv, HIS values for mango_1 saved in C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_his_features.csv

# %%
extract_lab(image_dirs, 
            save_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_lab_features.csv", 
            dataset="mango_1",
           resize=(64,64))
# Out:
# Processing 'mango_1' (Lab)...
# ...
# unripe: 100%|████████████████████████████████████████████████████████████████████████| 911/911 [00:09<00:00, 99.77it/s]
# LAB values for mango_1 saved in C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_lab_features.csv

# %%
extract_lbp(image_dirs, 
            save_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_lbp_features.csv",
            dataset="mango_1", 
           resize=(64,64))
# Out:
# Processing 'mango_1' (LBP)...
# ...
# unripe: 100%|███████████████████████████████████████████████████████████████████████| 911/911 [00:06<00:00, 144.27it/s]
# LBP values for mango_1 saved in C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_lbp_features.csv

# %%
extract_glcm(image_dirs, 
             save_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_glcm_features.csv", 
             dataset="mango_1",
           resize=(64,64))
# Out:
# Processing 'mango_1' (GLCM, angles=[0])...
# ...
# unripe: 100%|███████████████████████████████████████████████████████████████████████| 911/911 [00:06<00:00, 139.43it/s]
# GLCM values for mango_1 (angles=[0]) saved in C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_glcm_features.csv

# %% [markdown]
# ## Split test train class

# %%
from knn_classification import split_per_class

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_rgb_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_rgb_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_rgb_test.csv",
    feature="64x64_mango_1_rgb"
)

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_his_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_his_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_his_test.csv",
    feature="64x64_mango_1_his"
)

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_lab_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_lab_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_lab_test.csv",
    feature="64x64_mango_1_lab"
)

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_lbp_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_lbp_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_lbp_test.csv",
    feature="64x64_mango_1_lbp"
)

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_glcm_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_glcm_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_glcm_test.csv",
    feature="64x64_mango_1_glcm"
)
# Out:
#  Train set for 64x64_mango_1_rgb saved in C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_rgb_train.csv (2088 samples)
#  Test set for 64x64_mango_1_rgb saved in C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_rgb_test.csv (523 samples)
#  Train set for 64x64_mango_1_his saved in C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_his_train.csv (2088 samples)
#  Test set for 64x64_mango_1_his saved in C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_his_test.csv (523 samples)
#  Train set for 64x64_mango_1_lab saved in C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_lab_train.csv (2088 samples)
#  Test set for 64x64_mango_1_lab saved in C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_lab_test.csv (523 samples)
#  Train set for 64x64_mango_1_lbp saved in C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_lbp_train.csv (2088 samples)
#  Test set for 64x64_mango_1_lbp saved in C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_lbp_test.csv (523 samples)
# ...

# %% [markdown]
# ## KNN = 1,3,5,7

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_rgb_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_rgb_test.csv",
    feature="64x64_mango1_rgb",
    class_order=['unripe', 'ripe', 'overripe']
)
# Out:
# --- KNN (k=1) on 64x64_mango1_rgb Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.9415    0.8798    0.9096       183
#         ripe     0.7384    0.7384    0.7384       172
#     overripe     0.6667    0.7143    0.6897       168
#
#     accuracy                         0.7801       523
#    macro avg     0.7822    0.7775    0.7792       523
# weighted avg     0.7864    0.7801    0.7826       523
#
# Training time: 0.0030 seconds
# --- KNN (k=3) on 64x64_mango1_rgb Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.9653    0.9126    0.9382       183
#         ripe     0.7600    0.7733    0.7666       172
#     overripe     0.7143    0.7440    0.7289       168
#
#     accuracy                         0.8126       523
#    macro avg     0.8132    0.8100    0.8112       523
# weighted avg     0.8172    0.8126    0.8145       523
#
# Training time: 0.0030 seconds
# ...

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_his_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_his_test.csv",
    feature="64x64_mango1_his",
   class_order=['unripe', 'ripe', 'overripe']
)
# Out:
# --- KNN (k=1) on 64x64_mango1_his Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.9659    0.9290    0.9471       183
#         ripe     0.8436    0.8779    0.8604       172
#     overripe     0.8452    0.8452    0.8452       168
#
#     accuracy                         0.8853       523
#    macro avg     0.8849    0.8840    0.8842       523
# weighted avg     0.8869    0.8853    0.8859       523
#
# Training time: 0.0030 seconds
# --- KNN (k=3) on 64x64_mango1_his Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.9497    0.9290    0.9392       183
#         ripe     0.8276    0.8372    0.8324       172
#     overripe     0.8118    0.8214    0.8166       168
#
#     accuracy                         0.8642       523
#    macro avg     0.8630    0.8625    0.8627       523
# weighted avg     0.8652    0.8642    0.8647       523
#
# Training time: 0.0030 seconds
# ...

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_lab_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_lab_test.csv",
    feature="64x64_mango1_lab",
    class_order=['unripe', 'ripe', 'overripe']
)
# Out:
# --- KNN (k=1) on 64x64_mango1_lab Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.9655    0.9180    0.9412       183
#         ripe     0.9125    0.8488    0.8795       172
#     overripe     0.8201    0.9226    0.8683       168
#
#     accuracy                         0.8967       523
#    macro avg     0.8994    0.8965    0.8963       523
# weighted avg     0.9014    0.8967    0.8975       523
#
# Training time: 0.0030 seconds
# --- KNN (k=3) on 64x64_mango1_lab Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.9770    0.9290    0.9524       183
#         ripe     0.8944    0.8372    0.8649       172
#     overripe     0.8085    0.9048    0.8539       168
#
#     accuracy                         0.8910       523
#    macro avg     0.8933    0.8903    0.8904       523
# weighted avg     0.8957    0.8910    0.8920       523
#
# Training time: 0.0020 seconds
# ...

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_lbp_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_lbp_test.csv",
    feature="64x64_mango1_lbp",
    class_order=['unripe', 'ripe', 'overripe']
)
# Out:
# --- KNN (k=1) on 64x64_mango1_lbp Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.9064    0.8470    0.8757       183
#         ripe     0.8735    0.8430    0.8580       172
#     overripe     0.8118    0.8988    0.8531       168
#
#     accuracy                         0.8623       523
#    macro avg     0.8639    0.8629    0.8623       523
# weighted avg     0.8652    0.8623    0.8626       523
#
# Training time: 0.0010 seconds
# C:\Users\User\anaconda3\envs\fyp_env\lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
# ...

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_glcm_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_1\64x64_glcm_test.csv",
    feature="64x64_mango1_glcm",
    class_order=['unripe', 'ripe', 'overripe']
)
# Out:
# --- KNN (k=1) on 64x64_mango1_glcm Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.9071    0.9071    0.9071       183
#         ripe     0.7805    0.7442    0.7619       172
#     overripe     0.7330    0.7679    0.7500       168
#
#     accuracy                         0.8088       523
#    macro avg     0.8068    0.8064    0.8063       523
# weighted avg     0.8095    0.8088    0.8089       523
#
# Training time: 0.0030 seconds
# --- KNN (k=3) on 64x64_mango1_glcm Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.8950    0.8852    0.8901       183
#         ripe     0.8065    0.7267    0.7645       172
#     overripe     0.6898    0.7679    0.7268       168
#
#     accuracy                         0.7954       523
#    macro avg     0.7971    0.7933    0.7938       523
# weighted avg     0.8000    0.7954    0.7963       523
#
# Training time: 0.0030 seconds
# ...
