# %% [markdown]
# ## 64x64

# %%
from feature_extraction import (extract_rgb_his, extract_lab, extract_glcm, extract_lbp)

image_dirs = [
    r"C:\Users\User\Desktop\FYP\Dataset\mango_2\processed\03_augmented\ripe",
    r"C:\Users\User\Desktop\FYP\Dataset\mango_2\processed\03_augmented\unripe"
]

# %%
extract_rgb_his(image_dirs, 
                        rgb_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_rgb_features.csv",
                        his_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_his_features.csv",
                        dataset="mango_2",
                        resize=(64,64))
# Out:
# Processing 'mango_2' (RGB+HIS)...
# ...
# unripe: 100%|███████████████████████████████████████████████████████████████████████| 400/400 [00:01<00:00, 327.74it/s]
# RGB values for mango_2 saved in C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_rgb_features.csv, HIS values for mango_2 saved in C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_his_features.csv

# %%
extract_lab(image_dirs, 
            save_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_lab_features.csv", 
            dataset="mango_2",
           resize=(64,64))
# Out:
# Processing 'mango_2' (Lab)...
# ...
# unripe: 100%|███████████████████████████████████████████████████████████████████████| 400/400 [00:01<00:00, 250.20it/s]
# LAB values for mango_2 saved in C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_lab_features.csv

# %%
extract_lbp(image_dirs, 
            save_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_lbp_features.csv",
            dataset="mango_2", 
           resize=(64,64))
# Out:
# Processing 'mango_2' (LBP)...
# ...
# unripe: 100%|███████████████████████████████████████████████████████████████████████| 400/400 [00:01<00:00, 299.25it/s]
# LBP values for mango_2 saved in C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_lbp_features.csv

# %%
extract_glcm(image_dirs, 
             save_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_glcm_features.csv", 
             dataset="mango_2",
           resize=(64,64))
# Out:
# Processing 'mango_2' (GLCM, angles=[0])...
# ...
# unripe: 100%|███████████████████████████████████████████████████████████████████████| 400/400 [00:01<00:00, 261.70it/s]
# GLCM values for mango_2 (angles=[0]) saved in C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_glcm_features.csv

# %% [markdown]
# ## Split test train class

# %%
from knn_classification import split_per_class

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_rgb_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_rgb_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_rgb_test.csv",
    feature="64x64_mango_2_rgb"
)

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_his_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_his_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_his_test.csv",
    feature="64x64_mango_2_his"
)

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_lab_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_lab_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_lab_test.csv",
    feature="64x64_mango_2_lab"
)


split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_lbp_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_lbp_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_lbp_test.csv",
    feature="64x64_mango_2_lbp"
)

split_per_class(
    csv_path=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_glcm_features.csv",
    train_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_glcm_train.csv",
    test_output=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_glcm_test.csv",
    feature="64x64_mango_2_glcm"
)
# Out:
#  Train set for 64x64_mango_2_rgb saved in C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_rgb_train.csv (660 samples)
#  Test set for 64x64_mango_2_rgb saved in C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_rgb_test.csv (165 samples)
#  Train set for 64x64_mango_2_his saved in C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_his_train.csv (660 samples)
#  Test set for 64x64_mango_2_his saved in C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_his_test.csv (165 samples)
#  Train set for 64x64_mango_2_lab saved in C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_lab_train.csv (660 samples)
#  Test set for 64x64_mango_2_lab saved in C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_lab_test.csv (165 samples)
#  Train set for 64x64_mango_2_lbp saved in C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_lbp_train.csv (660 samples)
#  Test set for 64x64_mango_2_lbp saved in C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_lbp_test.csv (165 samples)
# ...

# %% [markdown]
# ## KNN = 1,3,5,7

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_rgb_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_rgb_test.csv",
    feature="64x64_mango2_rgb",
    class_order=['unripe', 'ripe']
)
# Out:
# --- KNN (k=1) on 64x64_mango2_rgb Feature ---
#               precision    recall  f1-score   support
#
#       unripe     1.0000    1.0000    1.0000        80
#         ripe     1.0000    1.0000    1.0000        85
#
#     accuracy                         1.0000       165
#    macro avg     1.0000    1.0000    1.0000       165
# weighted avg     1.0000    1.0000    1.0000       165
#
# Training time: 0.0010 seconds
# --- KNN (k=3) on 64x64_mango2_rgb Feature ---
#               precision    recall  f1-score   support
#
#       unripe     1.0000    1.0000    1.0000        80
#         ripe     1.0000    1.0000    1.0000        85
#
#     accuracy                         1.0000       165
#    macro avg     1.0000    1.0000    1.0000       165
# weighted avg     1.0000    1.0000    1.0000       165
#
# Training time: 0.0020 seconds
# --- KNN (k=5) on 64x64_mango2_rgb Feature ---
#               precision    recall  f1-score   support
#
# ...

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_his_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_his_test.csv",
    feature="64x64_mango2_his",
    class_order=['unripe', 'ripe']
)
# Out:
# --- KNN (k=1) on 64x64_mango2_his Feature ---
#               precision    recall  f1-score   support
#
#       unripe     1.0000    1.0000    1.0000        80
#         ripe     1.0000    1.0000    1.0000        85
#
#     accuracy                         1.0000       165
#    macro avg     1.0000    1.0000    1.0000       165
# weighted avg     1.0000    1.0000    1.0000       165
#
# Training time: 0.0010 seconds
# --- KNN (k=3) on 64x64_mango2_his Feature ---
#               precision    recall  f1-score   support
#
#       unripe     1.0000    1.0000    1.0000        80
#         ripe     1.0000    1.0000    1.0000        85
#
#     accuracy                         1.0000       165
#    macro avg     1.0000    1.0000    1.0000       165
# weighted avg     1.0000    1.0000    1.0000       165
#
# Training time: 0.0010 seconds
# --- KNN (k=5) on 64x64_mango2_his Feature ---
#               precision    recall  f1-score   support
#
# ...

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_lab_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_lab_test.csv",
    feature="64x64_mango2_lab",
    class_order=['unripe', 'ripe']
)
# Out:
# --- KNN (k=1) on 64x64_mango2_lab Feature ---
#               precision    recall  f1-score   support
#
#       unripe     1.0000    1.0000    1.0000        80
#         ripe     1.0000    1.0000    1.0000        85
#
#     accuracy                         1.0000       165
#    macro avg     1.0000    1.0000    1.0000       165
# weighted avg     1.0000    1.0000    1.0000       165
#
# Training time: 0.0020 seconds
# --- KNN (k=3) on 64x64_mango2_lab Feature ---
#               precision    recall  f1-score   support
#
#       unripe     1.0000    1.0000    1.0000        80
#         ripe     1.0000    1.0000    1.0000        85
#
#     accuracy                         1.0000       165
#    macro avg     1.0000    1.0000    1.0000       165
# weighted avg     1.0000    1.0000    1.0000       165
#
# Training time: 0.0010 seconds
# --- KNN (k=5) on 64x64_mango2_lab Feature ---
#               precision    recall  f1-score   support
#
# ...

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_lbp_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_lbp_test.csv",
    feature="64x64_mango2_lbp",
    class_order=['unripe', 'ripe']
)
# Out:
# --- KNN (k=1) on 64x64_mango2_lbp Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.9753    0.9875    0.9814        80
#         ripe     0.9881    0.9765    0.9822        85
#
#     accuracy                         0.9818       165
#    macro avg     0.9817    0.9820    0.9818       165
# weighted avg     0.9819    0.9818    0.9818       165
#
# Training time: 0.0010 seconds
# C:\Users\User\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\User\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
# ...

# %%
from knn_classification import knn_classification

knn_classification(
    train_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_glcm_train.csv", 
    test_csv=r"C:\Users\User\Desktop\FYP\Dataset\mango_2\64x64_glcm_test.csv",
    feature="64x64_mango2_glcm",
    class_order=['unripe', 'ripe']
)
# Out:
# --- KNN (k=1) on 64x64_mango2_glcm Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.9750    0.9750    0.9750        80
#         ripe     0.9765    0.9765    0.9765        85
#
#     accuracy                         0.9758       165
#    macro avg     0.9757    0.9757    0.9757       165
# weighted avg     0.9758    0.9758    0.9758       165
#
# Training time: 0.0010 seconds
# --- KNN (k=3) on 64x64_mango2_glcm Feature ---
#               precision    recall  f1-score   support
#
#       unripe     0.9634    0.9875    0.9753        80
#         ripe     0.9880    0.9647    0.9762        85
#
#     accuracy                         0.9758       165
#    macro avg     0.9757    0.9761    0.9757       165
# weighted avg     0.9761    0.9758    0.9758       165
#
# Training time: 0.0010 seconds
# --- KNN (k=5) on 64x64_mango2_glcm Feature ---
#               precision    recall  f1-score   support
#
# ...
